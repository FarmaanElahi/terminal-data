# %%
import pickle

import pandas as pd

d = pickle.load(open('data/files/upstox_ohlcv.pkl', 'rb'))

# %%
d.keys()
# Out:
# dict_keys(['NSE:BAJAJ_AUTO', 'NSE:ELECTCAST', 'BSE:SENSEX', 'NSE:CNXENERGY', 'NSE:NIFTY_INDIA_MFG', 'NSE:CNXINFRA', 'NSE:CNXFMCG', 'NSE:CNXAUTO', 'NSE:CNXIT', 'NSE:CNXFINANCE', 'NSE:BANKNIFTY', 'NSE:CNX500', 'NSE:NIFTY', 'NSE:NIFTY_LARGEMID250', 'NSE:NIFTY_IND_DIGITAL', 'NSE:CNXMNC', 'NSE:NIFTY_TOTAL_MKT', 'NSE:CPSE', 'NSE:NIFTY_MICROCAP250', 'NSE:CNXCOMMODITIES', 'NSE:NIFTYALPHA50', 'NSE:CNXCONSUMPTION', 'NSE:NIFTYMIDCAP150', 'NSE:CNX100', 'NSE:CNXPSE', 'NSE:NIFTYSMLCAP250', 'NSE:NIFTYMIDCAP50', 'NSE:CNXMIDCAP', 'NSE:CNXSMALLCAP', 'NSE:NIFTY_MID_SELECT', 'NSE:NIFTY_HEALTHCARE', 'NSE:NIFTY_CONSR_DURL', 'NSE:NIFTY_OIL_AND_GAS', 'NSE:NIFTYPVTBANK', 'NSE:CNXMEDIA', 'NSE:CNXREALTY', 'NSE:CNX200', 'NSE:CNXMETAL', 'NSE:CNXPSUBANK', 'NSE:CNXPHARMA', 'NSE:NIFTYJR', 'NSE:NIFTY_IND_DEFENCE', 'NSE:NIFTYMIDSML400'])

# %%
df:pd.DataFrame = d['NSE:BAJAJ_AUTO']

# %%
df.head()
# Out:
#                open     high      low    close   volume
# Date
# 2020-09-28  2976.90  3022.30  2952.85  2966.35   902239
# 2020-09-29  2992.70  3011.00  2890.00  2897.50  1189292
# 2020-09-30  2897.55  2939.00  2870.00  2881.10  1095715
# 2020-10-01  2940.00  3113.95  2940.00  2985.40  4741959
# 2020-10-05  3016.40  3020.00  2930.05  2952.30   904981

# %%
len(d)
# Out:
# 2273

# %%
list(d.keys())
# Out:
# ['NSE:RELIANCE',
#  'NSE:HDFCBANK',
#  'NSE:AIRTELPP',
#  'NSE:BHARTIARTL',
#  'NSE:TCS',
#  'NSE:ICICIBANK',
#  'NSE:SBIN',
#  'NSE:BAJFINANCE',
#  'NSE:INFY',
#  'NSE:HINDUNILVR',
#  'NSE:LICI',
#  'NSE:LT',
#  'NSE:MARUTI',
#  'NSE:ITC',
#  'NSE:M&M',
#  'NSE:KOTAKBANK',
#  'NSE:SUNPHARMA',
#  'NSE:HCLTECH',
#  'NSE:AXISBANK',
#  'NSE:ULTRACEMCO',
#  'NSE:NTPC',
#  'NSE:BAJAJFINSV',
#  'NSE:HAL',
#  'NSE:ETERNAL',
#  'NSE:ADANIPORTS',
#  'NSE:ONGC',
#  'NSE:TITAN',
#  'NSE:DMART',
#  'NSE:ADANIENT',
#  'NSE:BEL',
#  'NSE:ADANIPOWER',
#  'NSE:JSWSTEEL',
#  'NSE:POWERGRID',
#  'NSE:TATAMOTORS',
#  'NSE:WIPRO',
#  'NSE:BAJAJ_AUTO',
#  'NSE:COALINDIA',
#  'NSE:ASIANPAINT',
#  'NSE:NESTLEIND',
#  'NSE:INDIGO',
#  'NSE:HYUNDAI',
#  'NSE:TATASTEEL',
#  'NSE:IOC',
#  'NSE:EICHERMOT',
#  'NSE:HINDZINC',
#  'NSE:JIOFIN',
#  'NSE:GRASIM',
#  'NSE:SBILIFE',
#  'NSE:DLF',
#  'NSE:VEDL',
#  'NSE:ADANIGREEN',
#  'NSE:HINDALCO',
#  'NSE:TRENT',
#  'NSE:HDFCLIFE',
#  'NSE:TVSMOTOR',
# ...
